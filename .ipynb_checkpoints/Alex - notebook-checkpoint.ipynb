# %%
import pandas as pd
from pandas import DataFrame
import itertools

# %%
questions = pd.read_csv("questions.csv")
paragraphs = pd.read_csv("paragraphs.csv")
sample = pd.read_csv("sample.csv")
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
# Test data
# It pairs all test question ids with all available paragraphs.
# 
# A question-paragraph id is generated by concatenating the id of the question to the symbol “#”
# and then to the paragraph id.
# 
# You will need to parse it to extract the two identifiers (e.g. question-id and paragraph-id). 
# 
# Format:
# id – identifier for question-paragraph pair 
# qpid – (question-id # para-id) – combined id or question and paragraph

# Pre-process training data

# Split qpid into qid and ParaId
test['qid'], test['ParaId'] = test['qpid'].str.split('#', 1).str

# Cast question id columns and paragraph id columns to int
test['qid'] = test['qid'].astype(int)
test['ParaId'] = test['ParaId'].astype(int)
train['qid'] = train['qid'].astype(int)
train['ParaId'] = train['ParaId'].astype(int)

# Join questions and paragraphs together using train dataset

qpid = pd.merge(train, questions, left_on='qid', right_on='qid', how='left')
qpid = pd.merge(qpid, paragraphs, left_on='ParaId', right_on='ParaId', how='left')

# %%
# This is your training data, showing the paragraphs that are relevant for the particular question.
# 
# Format:
# qid – id of question (from questions.csv)
# ParaId – paragraph id for correct answer (from paragraphs.csv)

train.head()
# Out:
#     qid  ParaId
# 0   580      21
# 1  1188     323
# 2  1072     226
# 3    15     499
# 4   589      28

# %%
# This is the what result of your model should look like and is the file that should be submitted for evaluation. 
# 
# Format:
# id – identifier for question-paragraph pair (from test.csv)
# target (provided by your model) – 1 if para-id is in the top 5 relevant paragraphs for question q-id, 0 otherwise

sample.head()
# Out:
#    id  target
# 0   0       1
# 1   1       1
# 2   2       1
# 3   3       1
# 4   4       1

# %%
# One paragraph can be the answer to multiple questions

train.groupby('ParaId').count().head()
# Out:
#         qid
# ParaId
# 2         1
# 3         1
# 5         6
# 6         1
# 7         4

# %%
questions.head()
# Out:
#     qid                                              qtext
# 0   580  Can I delay paying taxes on my advanced commis...
# 1  1188  I received a dividend from a corporation that ...
# 2  1072  If I purchased but did not cash a coowned bond...
# 3    15  I work for a state or local government or a ta...
# 4   589  My employer promised a bonusaward Do I need to...

# %%
qpid
# Out:
#       qid  ParaId                                              qtext  \
# 0     580      21  Can I delay paying taxes on my advanced commis...
# 1    1188     323  I received a dividend from a corporation that ...
# 2    1072     226  If I purchased but did not cash a coowned bond...
# 3      15     499  I work for a state or local government or a ta...
# 4     589      28  My employer promised a bonusaward Do I need to...
# 5    1378     461  What for do I use for section 179 depreciable ...
# 6    1374     481  My spouse and I both equally own and work on o...
# 7    1196     323             Does the US have a treaty with France?
# 8     990     260  Should the discount of a debt instrument purch...
# 9     869     134  Are there exceptions to the penalty for not re...
# 10   1292     399  If I rent out my home do I include proceeds in...
# 11    344     622                      What is shown on box RRB1099?
# 12    232     549  What methods of rolling over my eligible distr...
# ...

# %%
qpid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 676 entries, 0 to 675
# Data columns (total 10 columns):
# qid                676 non-null int64
# ParaId             676 non-null int64
# qtext              676 non-null object
# Chapter            676 non-null object
# Title              676 non-null object
# SectionTitle       651 non-null object
# SubsectionTitle    288 non-null object
# Source             676 non-null object
# FeatureType        676 non-null object
# ParaText           676 non-null object
# dtypes: int64(2), object(8)
# memory usage: 58.1+ KB

# %%
train_data = pd.DataFrame(columns= ['qid', 'ParaId', 'is_related'])
for i, row in qpid.iterrows():
    for y in pd.Series(range(1,101)):
        train_data.loc[y] = ['name', '2', '3']
        print(index, row['ParaId'])
# Out:
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 21
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# 0 323
# ...

# %%
paragraphs.ParaId.max()
# Out:
# 784

# %%
df.loc[i] = ['name' + str(i)] + list(randint(10, size=2))

# %%
df = pd.DataFrame(columns= ['Brand', 'Price'])

# %%
df
# Out:
# Empty DataFrame
# Columns: [Brand, Price]
# Index: []

# %%
train_data
# Out:
#       qid ParaId is_related
# 1    name      2          3
# 2    name      2          3
# 3    name      2          3
# 4    name      2          3
# 5    name      2          3
# 6    name      2          3
# 7    name      2          3
# 8    name      2          3
# 9    name      2          3
# 10   name      2          3
# 11   name      2          3
# 12   name      2          3
# 13   name      2          3
# 14   name      2          3
# 15   name      2          3
# 16   name      2          3
# 17   name      2          3
# 18   name      2          3
# 19   name      2          3
# 20   name      2          3
# 21   name      2          3
# 22   name      2          3
# 23   name      2          3
# 24   name      2          3
# 25   name      2          3
# 26   name      2          3
# 27   name      2          3
# 28   name      2          3
# 29   name      2          3
# 30   name      2          3
# ..    ...    ...        ...
# 71   name      2          3
# ...

# %%
df = pd.DataFrame([train['qid'], train['ParaId']]).T
df = pd.DataFrame([e for e in itertools.product(df.qid, df.ParaId)], columns=df.columns)

df['lunch'] = df["qid", "ParaId"].isin(["qid", "ParaId"])
# df['lunch'] = (df['qid'] == train['qid'] & df['ParaId'] == train['ParaId']).astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lunch'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df2 = pd.merge(df, train, left_on=['ParaId','qid'], right_on = ['qid','ParaId'], how='left')

# %%
df
# Out:
#         qid  ParaId
# 0       580      21
# 1       580     323
# 2       580     226
# 3       580     499
# 4       580      28
# 5       580     461
# 6       580     481
# 7       580     323
# 8       580     260
# 9       580     134
# 10      580     399
# 11      580     622
# 12      580     549
# 13      580      28
# 14      580      23
# 15      580      37
# 16      580     517
# 17      580     571
# 18      580      14
# 19      580     603
# 20      580     663
# 21      580     583
# 22      580     554
# 23      580     675
# 24      580     565
# 25      580      17
# 26      580     260
# 27      580      32
# 28      580     584
# 29      580      28
# ...     ...     ...
# 456946  172     517
# 456947  172     612
# 456948  172      72
# 456949  172     343
# 456950  172       6
# 456951  172     150
# 456952  172      37
# 456953  172     228
# 456954  172      20
# 456955  172     424
# 456956  172     564
# 456957  172     431
# 456958  172     452
# ...

# %%
df2 = pd.DataFrame([train['qid'], train['ParaId']]).T
df2['qid'] = df.apply(lambda row: 1 if row["qid"] == train["qid"] else 0, axis = 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-251-ef472cd0eda5> in <module>
#       1 df2 = pd.DataFrame([train['qid'], train['ParaId']]).T
# ----> 2 df2['qid'] = df.apply(lambda row: 1 if row["qid"] == train["qid"] else 0, axis = 1)
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# ...

# %%
df2
# Out:
#       qid  ParaId
# 0     580      21
# 1    1188     323
# 2    1072     226
# 3      15     499
# 4     589      28
# 5    1378     461
# 6    1374     481
# 7    1196     323
# 8     990     260
# 9     869     134
# 10   1292     399
# 11    344     622
# 12    232     549
# 13    753      28
# 14    748      23
# 15   1592      37
# 16   1770     517
# 17    154     571
# 18   1830      14
# 19    375     603
# 20    525     663
# 21   1759     583
# 22    122     554
# 23    556     675
# 24    251     565
# 25    566      17
# 26   1101     260
# 27    602      32
# 28    276     584
# 29    754      28
# ..    ...     ...
# 646  1846     517
# 647   395     612
# 648   687      72
# 649  1600     343
# 650   736       6
# 651   898     150
# 652   624      37
# 653  1535     228
# 654   577      20
# 655  1309     424
# 656   247     564
# 657  1311     431
# 658  1693     452
# 659   168     582
# 660   671      61
# 661   149     569
# 662   810      92
# 663   606      32
# ...

# %%
(df['qid'] == train['qid']) & (df['ParaId'] == train['ParaId'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-267-835c5e4b5792> in <module>
# ----> 1 (df['qid'] == train['qid']) & (df['ParaId'] == train['ParaId'])
#
# //anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1674
#    1675         elif isinstance(other, ABCSeries) and not self._indexed_same(other):
# -> 1676             raise ValueError("Can only compare identically-labeled "
#    1677                              "Series objects")
#    1678
#
# ValueError: Can only compare identically-labeled Series objects

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 456976 entries, 0 to 456975
# Data columns (total 2 columns):
# qid       456976 non-null int64
# ParaId    456976 non-null int64
# dtypes: int64(2)
# memory usage: 7.0 MB

# %%
df['qid'].isin(train['qid']) & df['ParaId'].isin(train['ParaId'])
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
# 25        True
# 26        True
# 27        True
# 28        True
# 29        True
#           ...
# 456946    True
# 456947    True
# 456948    True
# 456949    True
# 456950    True
# 456951    True
# 456952    True
# 456953    True
# 456954    True
# 456955    True
# 456956    True
# 456957    True
# 456958    True
# 456959    True
# 456960    True
# 456961    True
# 456962    True
# 456963    True
# 456964    True
# 456965    True
# 456966    True
# 456967    True
# 456968    True
# 456969    True
# 456970    True
# 456971    True
# 456972    True
# ...

# %%
df2 = pd.merge(df, train, left_on=['qid', 'ParaId'], right_on = ['qid','ParaId'], how='left')
